# %% [markdown]
# <a href="https://colab.research.google.com/github/semadenipaul/cse380-notebooks/blob/master/14_1_My_Final_Grade_Claim_for_W21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 14_1_My_Final_Grade_Claim_for_W21.ipynb
# ## CSE 380 Discrete Mathematics II
# ### Winter 2021
# #### Final Grade Claim for Paul Semadeni

# %%
from google.colab import files
from IPython.display import Image

# %%
file = files.upload()
# Out:
#      <input type="file" id="files-7f33d040-ee59-4a3b-853b-b58de21da328" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f33d040-ee59-4a3b-853b-b58de21da328">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving download.png to download.png

# %%
Image('download.png')

# %% [markdown]
# # Top Evidences
#
# 1. [The Pigeonhole Problem](https://colab.research.google.com/github/semadenipaul/cse380-notebooks/blob/master/12_2_Ponder_and_Prove_The_Pigeonhole_Principle.ipynb#scrollTo=vRKIt3NOzkwH)
#
# 2. [Speeding up functions in week 11](https://colab.research.google.com/github/semadenipaul/cse380-notebooks/blob/master/11_2_Ponder_and_Prove_Verifying_Graph_Properties.ipynb#scrollTo=_E77JvrzViCZ)
#
# 3. Claiming an "A"

# %% [markdown]
# # How I went Above and Beyond
#
# Week 9: [Did Further Research on Huffman Trees and discussed it with my wife](https://colab.research.google.com/github/semadenipaul/cse380-notebooks/blob/master/09_2_Ponder_and_Prove_Data_Compression.ipynb#scrollTo=d-sXEeq60C3W)
#
# Week 10: [Purely Functional Programming in Week 10](https://colab.research.google.com/github/semadenipaul/cse380-notebooks/blob/master/10_2_Ponder_and_Prove_Spanning_Trees.ipynb#scrollTo=KGFaeCezjRKG)
#
# Week 11: [Expanded my knowledge of cliques and anti-cliques.](https://colab.research.google.com/github/semadenipaul/cse380-notebooks/blob/master/11_2_Ponder_and_Prove_Verifying_Graph_Properties.ipynb#scrollTo=mJHvoj6GokaZ)
#
# Week 12:
#
# In week 12, I was fascinated with paradoxes. I went above and beyond by looking for paradoxes in the scriptures. One of my favorites that I found is in John 4:5-29. This is where Jesus Christ is teaching the Samaritan woman at the well. In verses 13 and 14, the Savior says, "Jesus answered and said unto her, Whosoever drinketh of this water shall thirst again: But whosoever drinketh of the water that I shall give him shall never thirst." This is a paradox because the Savior is offering water that if one drinks, they will never thirst again. If you compare this life to being a marathon, it is physically impossible to run a 100 mile race with just one drink of water. The desire for water and would indefinitely make someone thirsty again throughout the marathon.
#
# week 13:
#
# As my group and I worked on the Ponder and Prove for week 13, we were impressed with John Conway's FACTRAN. In order to understand it more, we researched about it. Some of the sources we found include:
#
# https://en.wikipedia.org/wiki/FRACTRAN
#
# https://mathworld.wolfram.com/FRACTRAN.html
#
# I tried to talk to Maddie about this, but it was kind of over her head.

# %% [markdown]
# ## During your five minutes

# %% [markdown]
# The plan is for you to have your document loaded up in your browser ready to walk me through it, in this order:
#
# 1. Show me your flowchart decision path, with the **leaf $\equiv$ claimed grade** highlighted.
# 2. Show me and take a minute each to talk about your evidences (Top 3 or 2) and your **previously recorded** above and beyond behaviors.
#
# Test your links beforehand to make sure they work! A smooth transition between the different items you're presenting is the goal.
